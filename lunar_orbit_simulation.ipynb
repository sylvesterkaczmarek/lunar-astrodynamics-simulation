# %% [markdown]
# # Lunar J2 Precession Validation
#
# This notebook uses the tested `lunar_astrodynamics` package rather than duplicating the equations of motion. The demonstration orbit is inclined and mildly eccentric so that both RAAN and argument of periapsis are defined.

# %%
from pathlib import Path
from examples.j2_precession import write_outputs

# %%
metrics = write_outputs(orbits=40)
metrics

# %% [markdown]
# The automated test suite performs the same secular-rate comparison and also checks two-body invariants, axial angular-momentum conservation under J2, singular element handling, and invalid below-surface initial states. See `docs/model.md` for the model scope and frame assumptions.
